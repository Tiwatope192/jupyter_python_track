# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_products.csv")

# %%
df
# Out:
#       Index                                        Name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                                             Description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 3                                 Lawyer one than fire.
# ...

# %%
#filtering
df[df["Price"] > 500]
# Out:
#       Index                                        Name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 4         5                            Keyboard Freezer
# 5         6                           Smart Fridge Plus
# ...     ...                                         ...
# 9991   9992                                  Silent Fan
# 9992   9993           Smart Trimmer Stove Advanced Plus
# 9993   9994                                 Scale Clock
# 9994   9995                                     Blender
# 9995   9996                                   Powerbank
#
#                                           Description  \
# 0                           Catch enough role nearly.
# 1                           All movement yeah tax me.
# 2                 Quickly inside pull line lay start.
# 4                   Remain Congress blood plan voice.
# ...

# %%
specific_Names = ["Blender", "Powerbank"]
df[df["Price"].isin(specific_Names)]
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Brand, Category, Price, Currency, Stock, EAN, Color, Size, Availability, Internal ID]
# Index: []

# %%
df[df["Name"].str.contains("Powerbank")]
# Out:
#       Index                                          Name  \
# 11       12                      Mini Powerbank Lite Plus
# 15       16               Ultra Powerbank Scale Automatic
# 35       36  Clean Scale Speaker Powerbank Clean Wireless
# 36       37                        Advanced Fan Powerbank
# 51       52    Fast Powerbank Radio Automatic Touch Ultra
# ...     ...                                           ...
# 9876   9877             Ultra Powerbank Brush Charger Pro
# 9882   9883                 Smart Mouse Powerbank Printer
# 9885   9886        Clean Dock Powerbank Speaker Automatic
# 9946   9947                              Silent Powerbank
# 9995   9996                                     Powerbank
#
#                                   Description                         Brand  \
# 11                            Still can tell.  Gentry, Vincent and Saunders
# 15    Against or catch tough nor wait reason.                  Macias Group
# ...

# %%
df.filter(items = ["Category", "Price"])
# Out:
#                  Category  Price
# 0          Kids' Clothing    585
# 1          Grooming Tools    992
# 2       Fishing & Hunting    940
# 3                Skincare    324
# 4     Laptops & Computers    908
# ...                   ...    ...
# 9995   Books & Stationery    567
# 9996              Cycling    300
# 9997    Fitness Equipment    399
# 9998   Kitchen Appliances     45
# 9999    Sports & Outdoors     31
#
# [10000 rows x 2 columns]

# %%
df.loc[2]
# Out:
# Index                                                   3
# Name            Smart Speakerphone Charger Eco Plus Clean
# Description           Quickly inside pull line lay start.
# Brand                                        Peck-Coleman
# Category                                Fishing & Hunting
# Price                                                 940
# Currency                                              USD
# Stock                                                 769
# EAN                                         7569143820621
# Color                                                Blue
# Size                                          Extra Large
# Availability                                    pre_order
# Internal ID                                            42
# Name: 2, dtype: object

# %%
df[df["Price"] < 100].sort_values(by = ["Price", "EAN"], ascending=False)
# Out:
#       Index                                         Name  \
# 2658   2659                                 Lamp Freezer
# 9183   9184                          Mixer Drone Toaster
# 6919   6920                      Smart Freezer Mixer One
# 7723   7724                      Automatic Brush Premium
# 3183   3184  Automatic Keyboard Toaster Monitor Wireless
# ...     ...                                          ...
# 7496   7497    Premium Microphone Headphones Touch Sense
# 6027   6028                 Advanced Powerbank Projector
# 6543   6544               Portable Microphone Headphones
# 4613   4614                       Advanced Treadmill 360
# 8432   8433             Clean Radio Iron Automatic Sense
#
#                                             Description  \
# 2658                              Feel music week foot.
# 9183                    Deep every range run home born.
# 6919                  Occur type order until for world.
# ...

# %%
df.set_index("Name", inplace = True) #setting the index to a column name

# %%
df
# Out:
#                                             Index  \
# Name
# Smart Fan Iron Cooker Go Wireless Portable      1
# Fan                                             2
# Smart Speakerphone Charger Eco Plus Clean       3
# Premium Grill Trimmer Portable                  4
# Keyboard Freezer                                5
# ...                                           ...
# Powerbank                                    9996
# Rechargeable Lamp Scanner Vacuum             9997
# Heater                                       9998
# Rechargeable Headphones Stove                9999
# Clean Charger Treadmill                     10000
#
#                                                                                   Description  \
# Name
# Smart Fan Iron Cooker Go Wireless Portable                          Catch enough role nearly.
# Fan                                                                 All movement yeah tax me.
# ...

# %%
df.loc["Heater"]
# Out:
#         Index                                        Description  \
# Name
# Heater    190                       Focus probably onto billion.
# Heater    193     Low even member scientist chair fill everyone.
# Heater   2595                            Trade join hand detail.
# Heater   3146            Short risk tree reveal community paper.
# Heater   3866                          Section wish over report.
# Heater   4545                             We everything to song.
# Heater   5746                     Actually just one concern car.
# Heater   5793         Next image thought large theory artist he.
# Heater   6392  Political perform professional term field auth...
# Heater   6672      Relationship later cold up sing get meet red.
# Heater   8675                            Act social TV although.
# Heater   9104  Soon right middle represent population represent.
# Heater   9626                      Leader attention party force.
# ...

# %%
df.reset_index(inplace = True) #To reset the index from name back to number
df
# Out:
#       index                                        Name  Index  \
# 0         0  Smart Fan Iron Cooker Go Wireless Portable      1
# 1         1                                         Fan      2
# 2         2   Smart Speakerphone Charger Eco Plus Clean      3
# 3         3              Premium Grill Trimmer Portable      4
# 4         4                            Keyboard Freezer      5
# ...     ...                                         ...    ...
# 9995   9995                                   Powerbank   9996
# 9996   9996            Rechargeable Lamp Scanner Vacuum   9997
# 9997   9997                                      Heater   9998
# 9998   9998               Rechargeable Headphones Stove   9999
# 9999   9999                     Clean Charger Treadmill  10000
#
#                                             Description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# ...

# %%
df.set_index(["Name", "Category"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23856\4273310766.py in ?()
# ----> 1 df.set_index(["Name", "Category"], inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['Category'] are in the columns"

# %%
df.columns = df.columns.str.strip()

# %%
df.set_index(["Brand", "Category"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23856\4176610724.py in ?()
# ----> 1 df.set_index(["Brand", "Category"], inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['Brand', 'Category'] are in the columns"

# %%
df.index
# Out:
# MultiIndex([(                    'Herman Ltd',         'Kids' Clothing'),
#             (       'Braun, King and Rollins',         'Grooming Tools'),
#             (                  'Peck-Coleman',      'Fishing & Hunting'),
#             (                     'Hines Ltd',               'Skincare'),
#             (       'Spence, Webster and Orr',    'Laptops & Computers'),
#             (      'Marks, Guzman and Cooley',     'Kitchen Appliances'),
#             (                'Newman-Barajas',      'Fishing & Hunting'),
#             ('Gutierrez, Singleton and Downs',               'Skincare'),
#             (                'Weber and Sons',     'Clothing & Apparel'),
#             (             'Humphrey and Sons', 'Beauty & Personal Care'),
#             ...
#             (               'Maldonado-Walsh',      'Sports & Outdoors'),
#             (                 'Floyd-Hensley',             'Automotive'),
# ...

# %%
print("Category" in df.columns)
# Out:
# False

# %%
df
# Out:
#                                              index  \
# Brand                   Category
# Herman Ltd              Kids' Clothing           0
# Braun, King and Rollins Grooming Tools           1
# Peck-Coleman            Fishing & Hunting        2
# Hines Ltd               Skincare                 3
# Spence, Webster and Orr Laptops & Computers      4
# ...                                            ...
# Castaneda-Harrison      Books & Stationery    9995
# Knapp-Key               Cycling               9996
# Meyer, Case and Mills   Fitness Equipment     9997
# Jones-Bell              Kitchen Appliances    9998
# Davis LLC               Sports & Outdoors     9999
#
#                                                                                    Name  \
# Brand                   Category
# Herman Ltd              Kids' Clothing       Smart Fan Iron Cooker Go Wireless Portable
# Braun, King and Rollins Grooming Tools                                              Fan
# ...

# %%
df.sort_index()
# Out:
#                                                      index  \
# Brand                        Category
# Abbott Ltd                   Fishing & Hunting        1777
# Abbott, Holden and Conrad    Shoes & Footwear         8670
# Abbott, Lynch and Warner     Health & Wellness        3849
# Abbott, Pitts and Charles    Books & Stationery        534
# Abbott, Zavala and Patrick   Beauty & Personal Care   1218
# ...                                                    ...
# Zuniga, Schwartz and Barber  Home & Kitchen           9751
# Zuniga, Zavala and Contreras Fishing & Hunting        1535
# Zuniga-Allen                 Automotive               3784
# Zuniga-Mcpherson             Kids' Clothing           2014
# Zuniga-Yates                 Clothing & Apparel       3125
#
#                                                                                             Name  \
# Brand                        Category
# ...

# %%
df.loc["Abbott Ltd"]
# Out:
#                    index                                      Name  Index  \
# Category
# Fishing & Hunting   1777  Fast Charger Treadmill Wireless 360 Edge   1778
#
#                                                          Description  Price  \
# Category
# Fishing & Hunting  Account themselves find condition doctor resea...     95
#
#                   Currency  Stock            EAN      Color Size  \
# Category
# Fishing & Hunting      USD    712  9830372648422  RosyBrown   XL
#
#                     Availability  Internal ID
# Category
# Fishing & Hunting  limited_stock           82

# %%
df.iloc[0]
# Out:
# index                                                    0
# Name            Smart Fan Iron Cooker Go Wireless Portable
# Index                                                    1
# Description                      Catch enough role nearly.
# Price                                                  585
# Currency                                               USD
# Stock                                                  194
# EAN                                          3968600833473
# Color                                             Cornsilk
# Size                                                5x7 in
# Availability                                 limited_stock
# Internal ID                                             54
# Name: (Herman Ltd, Kids' Clothing), dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                         Brand             Category  index  \
# 0                  Herman Ltd       Kids' Clothing      0
# 1     Braun, King and Rollins       Grooming Tools      1
# 2                Peck-Coleman    Fishing & Hunting      2
# 3                   Hines Ltd             Skincare      3
# 4     Spence, Webster and Orr  Laptops & Computers      4
# ...                       ...                  ...    ...
# 9995       Castaneda-Harrison   Books & Stationery   9995
# 9996                Knapp-Key              Cycling   9996
# 9997    Meyer, Case and Mills    Fitness Equipment   9997
# 9998               Jones-Bell   Kitchen Appliances   9998
# 9999                Davis LLC    Sports & Outdoors   9999
#
#                                             Name  Index  \
# 0     Smart Fan Iron Cooker Go Wireless Portable      1
# 1                                            Fan      2
# 2      Smart Speakerphone Charger Eco Plus Clean      3
# ...

# %%
group_by_frame = df.groupby("Name")["Price"].mean()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 group_by_frame_mean()
#
# NameError: name 'group_by_frame_mean' is not defined

# %%
 df.groupby("Name")["Price"].sum()
# Out:
# Name
# Advanced Bicycle                                              1778
# Advanced Bicycle Lock Fan                                     1567
# Advanced Bicycle Lock Fan Mini                                 955
# Advanced Bicycle Microphone Go                                  49
# Advanced Bicycle Scooter 360 Advanced                          530
#                                                               ...
# Wireless Webcam Stove Grill One                                 14
# Wireless Webcam Toaster                                         29
# Wireless Webcam Toaster Silent Prime                           778
# Wireless Webcam Trimmer Projector Silent Edge Rechargeable     700
# Wireless Webcam Webcam Stove                                   736
# Name: Price, Length: 7896, dtype: int64

# %%
df.groupby("Name").agg({"Price": ["mean", "max", "min", "sum", "count"], "Stock":["mean", "max", "min", "sum", "count"]})
# Out:
#                                                          Price            \
#                                                           mean  max  min
# Name
# Advanced Bicycle                                    592.666667  897  279
# Advanced Bicycle Lock Fan                           783.500000  962  605
# Advanced Bicycle Lock Fan Mini                      955.000000  955  955
# Advanced Bicycle Microphone Go                       49.000000   49   49
# Advanced Bicycle Scooter 360 Advanced               530.000000  530  530
# ...                                                        ...  ...  ...
# Wireless Webcam Stove Grill One                      14.000000   14   14
# Wireless Webcam Toaster                              29.000000   29   29
# Wireless Webcam Toaster Silent Prime                778.000000  778  778
# Wireless Webcam Trimmer Projector Silent Edge R...  700.000000  700  700
# Wireless Webcam Webcam Stove                        736.000000  736  736
#
# ...

# %%
df.groupby(["Brand", "Category"]).agg({"Price": ["mean", "max", "count", "sum"]})
# Out:
#                                                      Price
#                                                       mean  max count  sum
# Brand                        Category
# Abbott Ltd                   Fishing & Hunting        95.0   95     1   95
# Abbott, Holden and Conrad    Shoes & Footwear        800.0  800     1  800
# Abbott, Lynch and Warner     Health & Wellness       521.0  521     1  521
# Abbott, Pitts and Charles    Books & Stationery      527.0  527     1  527
# Abbott, Zavala and Patrick   Beauty & Personal Care  611.0  611     1  611
# ...                                                    ...  ...   ...  ...
# Zuniga, Schwartz and Barber  Home & Kitchen          664.0  664     1  664
# Zuniga, Zavala and Contreras Fishing & Hunting        71.0   71     1   71
# Zuniga-Allen                 Automotive              496.0  496     1  496
# Zuniga-Mcpherson             Kids' Clothing          969.0  969     1  969
# ...

# %%
#short_cut
df.groupby("Price").describe()
# Out:
#       index                                                              \
#       count         mean          std     min      25%     50%      75%
# Price
# 1      10.0  4607.200000  2569.621580  1032.0  2643.00  4867.0  6414.00
# 2      10.0  3551.200000  2766.369293  1070.0  1726.75  2421.0  4589.25
# 3      11.0  5998.090909  3169.240239   185.0  4659.00  7695.0  8234.00
# 4      12.0  4717.916667  3058.401319   328.0  2678.75  4723.5  6616.25
# 5       7.0  5790.428571  2694.264702  1421.0  4316.50  6218.0  7577.50
# ...     ...          ...          ...     ...      ...     ...      ...
# 995     9.0  5474.777778  2611.378265  1270.0  4076.00  6025.0  7822.00
# 996     7.0  5350.714286  1982.039078  3535.0  3859.50  4515.0  6435.00
# 997     9.0  5312.666667  1812.783495  2598.0  3635.00  5576.0  6654.00
# 998    11.0  5420.454545  2615.788346  2022.0  3239.00  5616.0  7484.50
# 999    16.0  5462.875000  2799.860041  1115.0  3361.25  5909.5  7683.50
#
# ...
