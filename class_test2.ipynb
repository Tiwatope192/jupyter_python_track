# %%
#dataset 2
#def extract_data():
    #pass
#def transform_data():
    #pass
#def load_data():
    #pass

# %%
import pandas as pd

# %%
df = pd.read_csv("products-10000.csv")

# %%
df
# Out:
#       Index                                        Name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                                             Description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 3                                 Lawyer one than fire.
# ...

# %%
df["Size"]
# Out:
# 0            5x7 in
# 1                 S
# 2       Extra Large
# 3          50x70 cm
# 4          10x10 cm
#            ...
# 9995         Medium
# 9996          Large
# 9997          Large
# 9998       12x18 in
# 9999         Medium
# Name: Size, Length: 10000, dtype: object

# %%
# Extract: read the dataset
def extract_data():
    df = pd.read_csv("products-10000.csv")
    return df

# %%
df.head(10)
# Out:
#    Index                                        Name  \
# 0      1  Smart Fan Iron Cooker Go Wireless Portable
# 1      2                                         Fan
# 2      3   Smart Speakerphone Charger Eco Plus Clean
# 3      4              Premium Grill Trimmer Portable
# 4      5                            Keyboard Freezer
# 5      6                           Smart Fridge Plus
# 6      7          Compact Dock One Portable Wireless
# 7      8           Premium Cooler Digital Portable X
# 8      9              Compact Fan Scooter Headphones
# 9     10                                Eco Dock Air
#
#                                       Description  \
# 0                       Catch enough role nearly.
# 1                       All movement yeah tax me.
# 2             Quickly inside pull line lay start.
# 3                           Lawyer one than fire.
# 4               Remain Congress blood plan voice.
# 5             Tell tend provide government voice.
# ...

# %%
#Standardising S to Small
def transform_data(df):
    df["Size"] = df["Size"].replace("S", "Small")
    return df

# %%
df = transform_data(df)
df
# Out:
#       Index                                        Name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                                             Description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 3                                 Lawyer one than fire.
# ...

# %%
def load_data(df):
    df.to_csv("cleaned products-10000.csv", index=False)

# %%
df.to_csv( r"C:\Users\userlab\Desktop\peju_python_flow\cleaned_products.csv", index=False)
