# %%
import pandas as pd
from sqlalchemy import create_engine
#creating an engine function is for database interfacing and connectivity

# %%
import psycopg2
#is a database driver that allows python communicate with postgresql database

# %%
#pip show psycopg2

# %%
#connecting sql alchemy to postgresql connection code to establish conn and write sql queries

# %%
engine = create_engine("postgresql+psycopg2://postgres:QztLWcoQoMcFPKoKgCyuDwUPjOHUYdtO@trolley.proxy.rlwy.net:50067/railway")

# %%
#running an sql query in python to result in a pd dataframe
df_categories = pd.read_sql(f" select * from public.categories", engine)

# %%
df_categories
# Out:
#    id            name          slug  is_active  \
# 0   1     Electronics   electronics       True
# 1   2        Clothing      clothing       True
# 2   3           Books         books       True
# 3   4  Home & Kitchen  home-kitchen       True
# 4   5          Sports        sports       True
#
#                         created_at                       updated_at
# 0 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 1 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 2 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 3 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 4 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00

# %%
df_coupons = pd.read_sql(f" select * from public.coupons", engine)

# %%
df_coupons
# Out:
#    id       code  discount_pct  max_uses  used_count  is_active expires_at  \
# 0   3    FLASH50          50.0        50           0       True       None
# 1   1  WELCOME10          10.0       500           1       True       None
# 2   2     SAVE20          20.0       100           1       True       None
#
#                         created_at                       updated_at
# 0 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 1 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:58:50.366166+00:00
# 2 2026-03-11 02:31:45.075615+00:00 2026-03-11 13:30:44.214771+00:00

# %%
df_customers = pd.read_sql(f" select * from public.customers", engine)

# %%
df_customers
# Out:
#       id first_name   last_name                       email  \
# 0      1       Test        User           testuser@test.com
# 1      2      Ahmed     Oladapo           biyiguy@gmail.com
# 2     53      Megan  Stephenson         donna55@example.com
# 3     54     Lauren     Flowers        judith52@example.net
# 4     55    Charles     Ramirez  proctorcharles@example.org
# ..   ...        ...         ...                         ...
# 119  170        Amy      Bailey     lewisjustin@example.com
# 120  171    Kathryn       Lopez   nunezmargaret@example.org
# 121  172       Cole      Miller         kelly73@example.net
# 122  173   Chidinma        Okeh    chidinmaokeh75@gmail.com
# 123  174       Lola       Bakre  Lardivahapparels@gmail.com
#
#                     phone                          address    city   state  \
# 0                    None                             None    None    None
# 1          +2349091390809                    230 borno way   lagos    Abia
# ...

# %%
df_inventory = pd.read_sql(f" select * from public.inventory", engine)

# %%
df_inventory.head(5)
# Out:
#    id  product_id  quantity  reorder_lvl                       created_at  \
# 0   2           2       499           20 2026-03-11 02:31:45.075615+00:00
# 1   4           4       499           20 2026-03-11 02:31:45.075615+00:00
# 2   6           6       499           20 2026-03-11 02:31:45.075615+00:00
# 3  14          14       496           20 2026-03-11 02:31:45.075615+00:00
# 4   3           3       499           20 2026-03-11 02:31:45.075615+00:00
#
#                         updated_at
# 0 2026-03-18 21:13:31.659486+00:00
# 1 2026-03-18 21:13:31.659486+00:00
# 2 2026-03-18 21:13:31.659486+00:00
# 3 2026-03-19 18:43:14.426457+00:00
# 4 2026-03-18 21:13:31.659486+00:00

# %%
df_order_items = pd.read_sql(f" select * from public.order_items", engine)

# %%
df_order_items.head(5)
# Out:
#     id  order_id  product_id  quantity  unit_price  total_price  \
# 0  608       201           1         1      299.99       299.99
# 1  609       202           3         3       35.00       105.00
# 2  610       202           6         1       39.99        39.99
# 3  611       203           7         3       89.99       269.97
# 4  612       203          12         1       79.00        79.00
#
#                         created_at                       updated_at
# 0 2026-03-11 02:47:25.274472+00:00 2026-03-11 02:47:25.274472+00:00
# 1 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 2 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 3 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 4 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00

# %%
df_orders = pd.read_sql(F" select * from public.orders", engine)

# %%
df_orders.head(5)
# Out:
#     id  customer_id  coupon_id     status  subtotal  discount_amount    total  \
# 0  201            1        NaN    pending    299.99              0.0   299.99
# 1  202            2        NaN    shipped    144.99              0.0   144.99
# 2  203           67        NaN    shipped   1023.92              0.0  1023.92
# 3  204           54        NaN  delivered    923.97              0.0   923.97
# 4  205            2        NaN  delivered    594.93              0.0   594.93
#
#                                            notes  \
# 0                                           None
# 1                                           None
# 2  Buy history pass professional technology not.
# 3                                           None
# 4                                           None
#
#                         created_at                       updated_at
# 0 2026-03-11 02:47:25.274472+00:00 2026-03-11 02:47:25.274472+00:00
# ...

# %%
df_payments = pd.read_sql(f" select * from public.payments", engine)

# %%
df_payments.head(5)
# Out:
#     id  order_id         method     status   amount  \
# 0  201       201           card  completed   299.99
# 1  202       202         paypal  completed   144.99
# 2  203       203  bank_transfer  completed  1023.92
# 3  204       204         paypal  completed   923.97
# 4  205       205           card  completed   594.93
#
#                               reference                       created_at  \
# 0  bfc477cb-7093-4442-819b-1e54bfe69c12 2026-03-11 02:47:25.274472+00:00
# 1  b53fd75f-1ef3-4a95-8f45-5accea26255c 2026-03-11 02:48:42.266872+00:00
# 2  71e4ae4c-6fbd-400f-8522-3118eef261dc 2026-03-11 02:48:42.266872+00:00
# 3  ae1cff6e-ff98-49d5-8321-c78cd6bd50d7 2026-03-11 02:48:42.266872+00:00
# 4  5d85bf0f-2ecd-40f9-8039-af3358599156 2026-03-11 02:48:42.266872+00:00
#
#                         updated_at
# 0 2026-03-11 02:47:25.274472+00:00
# 1 2026-03-11 02:48:42.266872+00:00
# 2 2026-03-11 02:48:42.266872+00:00
# 3 2026-03-11 02:48:42.266872+00:00
# ...

# %%
df_products = pd.read_sql(f" select * from public.products", engine)

# %%
df_products.head(5)
# Out:
#    id  category_id                  name                  slug  \
# 0   1            1    Samsung Galaxy A54    samsung-galaxy-a54
# 1   2            1  Wireless Earbuds Pro  wireless-earbuds-pro
# 2   3            1      USB-C Hub 7-in-1        usb-c-hub-7in1
# 3   4            1   Mechanical Keyboard   mechanical-keyboard
# 4   5            2     Classic White Tee     classic-white-tee
#
#                              description   price image_url  is_active  \
# 0           Mid-range Android smartphone  299.99      None       True
# 1      Noise-cancelling wireless earbuds   49.99      None       True
# 2                Multiport USB-C adapter   35.00      None       True
# 3  TKL mechanical keyboard, red switches   79.99      None       True
# 4             100% cotton unisex t-shirt   15.99      None       True
#
#                         created_at                       updated_at
# 0 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# ...

# %%
df_reviews = pd.read_sql(f" select * from public.reviews", engine)

# %%
df_reviews.head(5)
# Out:
#    id  product_id  customer_id  rating  \
# 0  21           1           58       1
# 1  22           1           62       5
# 2  23          12           66       5
# 3  24           4            1       3
# 4  25           2            2       1
#
#                                              comment  \
# 0  Him performance clearly part answer kitchen th...
# 1    Interesting television early recent generation.
# 2  Remain check set name culture consumer him lik...
# 3        Ball same movie structure human save share.
# 4                                               None
#
#                         created_at                       updated_at
# 0 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 1 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 2 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 3 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# ...

# %%
df_shipping = pd.read_sql(f" select * from public.shipping", engine)

# %%
df_shipping.tail(5)
# Out:
#       id  order_id       status carrier tracking_number           address  \
# 558  758       759  not_shipped    None            None     230 borno way
# 559  759       760  not_shipped    None            None     230 borno way
# 560  760       761  not_shipped    None            None  23 seidu okeleji
# 561  761       762  not_shipped    None            None     230 borno way
# 562  762       763  not_shipped    None            None     230 borno way
#
#       city   state  country postal_code shipped_at delivered_at  \
# 558  lagos    Abia  Nigeria      234101        NaT          NaT
# 559  lagos    Abia  Nigeria      234101        NaT          NaT
# 560  Lagos  Logos   Nigeria       10001        NaT          NaT
# 561  lagos    Abia  Nigeria      234101        NaT          NaT
# 562  lagos    Abia  Nigeria      234101        NaT          NaT
#
#                           created_at                       updated_at
# ...

# %%
from sqlalchemy import inspect
#this function creates an introspection object that gets info about daabase and retrieve columns

# %%
insp = inspect(engine)
#examines schemas, table and columns, keys etc

# %%
#engine = create_engine("postgresql+psycopg2://postgres:QztLWcoQoMcFPKoKgCyuDwUPjOHUYdtO@trolley.proxy.rlwy.net:50067/railway")

# %%
table_names = insp.get_table_names(schema='public')
print("table_names:\n", table_names)
#insp get the table from schema and returns a table list as strings, for verification
# Out:
# table_names:
#  ['categories', 'products', 'customers', 'orders', 'coupons', 'order_items', 'payments', 'shipping', 'inventory', 'reviews']

# %%
#table_list = ["categories", "coupons", "customers", "inventory", "order_items", "orders", "payments", "products", "reviews", "shipping"]

# %%
#mapping tables to sql queries in a .py it allows iteration

# %%
table_dict = {"categories": "select * from categories", 
          "coupons": "select * from coupons", 
          "customers": "select * from customers",
          "inventory": "select * from inventory",
         "order_items": "select * from order_items",
         "orders": "select * from orders",
         "payments": "select * from payments",
         "products": "select * from products",
         "reviews": "select * from reviews",
         "shipping": "select * from shipping"}

# %%
table_dict
# Out:
# {'categories': 'select * from categories',
#  'coupons': 'select * from coupons',
#  'customers': 'select * from customers',
#  'inventory': 'select * from inventory',
#  'order_items': 'select * from order_items',
#  'orders': 'select * from orders',
#  'payments': 'select * from payments',
#  'products': 'select * from products',
#  'reviews': 'select * from reviews',
#  'shipping': 'select * from shipping'}

# %%
#dfs_list = []

# %%
#for table in table_list:
    #dfs_[table] = pd.read_sql(f" select * from {table}", engine)
    #dfs_list.append(dfs)

# %%
#dfs_list[0

# %%
dfs_dict = {}

# %%
for table_name, sql_query in table_dict.items():
    df = pd.read_sql(sql_query, engine)
    dfs_dict[table_name] = df

# %%
categories_df = dfs_dict["categories"]

# %%
categories_df.tail(10)
# Out:
#    id            name          slug  is_active  \
# 0   1     Electronics   electronics       True
# 1   2        Clothing      clothing       True
# 2   3           Books         books       True
# 3   4  Home & Kitchen  home-kitchen       True
# 4   5          Sports        sports       True
#
#                         created_at                       updated_at
# 0 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 1 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 2 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 3 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 4 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00

# %%
coupons_df = dfs_dict["coupons"]

# %%
coupons_df.tail(5)
# Out:
#    id       code  discount_pct  max_uses  used_count  is_active expires_at  \
# 0   3    FLASH50          50.0        50           0       True       None
# 1   1  WELCOME10          10.0       500           1       True       None
# 2   2     SAVE20          20.0       100           1       True       None
#
#                         created_at                       updated_at
# 0 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# 1 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:58:50.366166+00:00
# 2 2026-03-11 02:31:45.075615+00:00 2026-03-11 13:30:44.214771+00:00

# %%
customer_df = dfs_dict["customers"]

# %%
customer_df.head(8)
# Out:
#    id first_name   last_name                       email  \
# 0   1       Test        User           testuser@test.com
# 1   2      Ahmed     Oladapo           biyiguy@gmail.com
# 2  53      Megan  Stephenson         donna55@example.com
# 3  54     Lauren     Flowers        judith52@example.net
# 4  55    Charles     Ramirez  proctorcharles@example.org
# 5  56       Anna       James         colin49@example.org
# 6  57    Kristen    Williams    cynthiagibbs@example.net
# 7  58    Michael    Davidson        woodryan@example.com
#
#                   phone                    address           city state  \
# 0                  None                       None           None  None
# 1        +2349091390809              230 borno way          lagos  Abia
# 2      001-292-983-4859  10808 Mary Mall Suite 271         Ibadan  None
# 3     (396)349-3118x207          9945 Pamela Field           Kano  None
# 4  001-876-237-8316x690         951 Adam Mountains          Lagos  None
# ...

# %%
inventory_df = dfs_dict["inventory"]

# %%
inventory_df.head(5)
# Out:
#    id  product_id  quantity  reorder_lvl                       created_at  \
# 0   2           2       499           20 2026-03-11 02:31:45.075615+00:00
# 1   4           4       499           20 2026-03-11 02:31:45.075615+00:00
# 2   6           6       499           20 2026-03-11 02:31:45.075615+00:00
# 3  14          14       496           20 2026-03-11 02:31:45.075615+00:00
# 4   3           3       499           20 2026-03-11 02:31:45.075615+00:00
#
#                         updated_at
# 0 2026-03-18 21:13:31.659486+00:00
# 1 2026-03-18 21:13:31.659486+00:00
# 2 2026-03-18 21:13:31.659486+00:00
# 3 2026-03-19 18:43:14.426457+00:00
# 4 2026-03-18 21:13:31.659486+00:00

# %%
order_items_df = dfs_dict["order_items"]

# %%
order_items_df.head(5)
# Out:
#     id  order_id  product_id  quantity  unit_price  total_price  \
# 0  608       201           1         1      299.99       299.99
# 1  609       202           3         3       35.00       105.00
# 2  610       202           6         1       39.99        39.99
# 3  611       203           7         3       89.99       269.97
# 4  612       203          12         1       79.00        79.00
#
#                         created_at                       updated_at
# 0 2026-03-11 02:47:25.274472+00:00 2026-03-11 02:47:25.274472+00:00
# 1 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 2 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 3 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 4 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00

# %%
orders_df = dfs_dict["orders"]

# %%
orders_df.head(5)
# Out:
#     id  customer_id  coupon_id     status  subtotal  discount_amount    total  \
# 0  201            1        NaN    pending    299.99              0.0   299.99
# 1  202            2        NaN    shipped    144.99              0.0   144.99
# 2  203           67        NaN    shipped   1023.92              0.0  1023.92
# 3  204           54        NaN  delivered    923.97              0.0   923.97
# 4  205            2        NaN  delivered    594.93              0.0   594.93
#
#                                            notes  \
# 0                                           None
# 1                                           None
# 2  Buy history pass professional technology not.
# 3                                           None
# 4                                           None
#
#                         created_at                       updated_at
# 0 2026-03-11 02:47:25.274472+00:00 2026-03-11 02:47:25.274472+00:00
# ...

# %%
payments_df = dfs_dict["payments"]

# %%
payments_df.head(5)
# Out:
#     id  order_id         method     status   amount  \
# 0  201       201           card  completed   299.99
# 1  202       202         paypal  completed   144.99
# 2  203       203  bank_transfer  completed  1023.92
# 3  204       204         paypal  completed   923.97
# 4  205       205           card  completed   594.93
#
#                               reference                       created_at  \
# 0  bfc477cb-7093-4442-819b-1e54bfe69c12 2026-03-11 02:47:25.274472+00:00
# 1  b53fd75f-1ef3-4a95-8f45-5accea26255c 2026-03-11 02:48:42.266872+00:00
# 2  71e4ae4c-6fbd-400f-8522-3118eef261dc 2026-03-11 02:48:42.266872+00:00
# 3  ae1cff6e-ff98-49d5-8321-c78cd6bd50d7 2026-03-11 02:48:42.266872+00:00
# 4  5d85bf0f-2ecd-40f9-8039-af3358599156 2026-03-11 02:48:42.266872+00:00
#
#                         updated_at
# 0 2026-03-11 02:47:25.274472+00:00
# 1 2026-03-11 02:48:42.266872+00:00
# 2 2026-03-11 02:48:42.266872+00:00
# 3 2026-03-11 02:48:42.266872+00:00
# ...

# %%
products_df = dfs_dict["products"]

# %%
products_df.head(5)
# Out:
#    id  category_id                  name                  slug  \
# 0   1            1    Samsung Galaxy A54    samsung-galaxy-a54
# 1   2            1  Wireless Earbuds Pro  wireless-earbuds-pro
# 2   3            1      USB-C Hub 7-in-1        usb-c-hub-7in1
# 3   4            1   Mechanical Keyboard   mechanical-keyboard
# 4   5            2     Classic White Tee     classic-white-tee
#
#                              description   price image_url  is_active  \
# 0           Mid-range Android smartphone  299.99      None       True
# 1      Noise-cancelling wireless earbuds   49.99      None       True
# 2                Multiport USB-C adapter   35.00      None       True
# 3  TKL mechanical keyboard, red switches   79.99      None       True
# 4             100% cotton unisex t-shirt   15.99      None       True
#
#                         created_at                       updated_at
# 0 2026-03-11 02:31:45.075615+00:00 2026-03-11 02:31:45.075615+00:00
# ...

# %%
reviews_df = dfs_dict["reviews"]

# %%
reviews_df.head(5)
# Out:
#    id  product_id  customer_id  rating  \
# 0  21           1           58       1
# 1  22           1           62       5
# 2  23          12           66       5
# 3  24           4            1       3
# 4  25           2            2       1
#
#                                              comment  \
# 0  Him performance clearly part answer kitchen th...
# 1    Interesting television early recent generation.
# 2  Remain check set name culture consumer him lik...
# 3        Ball same movie structure human save share.
# 4                                               None
#
#                         created_at                       updated_at
# 0 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 1 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 2 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# 3 2026-03-11 02:48:42.266872+00:00 2026-03-11 02:48:42.266872+00:00
# ...

# %%
shipping_df = dfs_dict["shipping"]

# %%
shipping_df.head(5)
# Out:
#     id  order_id       status carrier tracking_number               address  \
# 0  200       201  not_shipped    None            None           123 Test St
# 1  201       202   in_transit   FedEx   BF61506170282         230 borno way
# 2  202       203   in_transit   FedEx   QG37272864561  1042 Joseph Motorway
# 3  203       204    delivered     DHL   JL37932870874     9945 Pamela Field
# 4  204       205    delivered     DHL   KC27343694512         230 borno way
#
#     city state  country postal_code                       shipped_at  \
# 0  Lagos  None  Nigeria        None                              NaT
# 1  lagos  None  Nigeria        None 2025-11-16 02:31:46.083152+00:00
# 2  Lagos  None  Nigeria        None 2025-11-07 00:17:46.235412+00:00
# 3   Kano  None  Nigeria        None 2025-09-13 06:40:46.603995+00:00
# 4  lagos  None  Nigeria        None 2026-01-04 11:41:47.019277+00:00
#
#                       delivered_at                       created_at  \
# ...

# %%
from sqlalchemy import create_engine, inspect

# %%
insp = inspect(engine)

# %%
engine = create_engine("postgresql+psycopg2://postgres:QztLWcoQoMcFPKoKgCyuDwUPjOHUYdtO@trolley.proxy.rlwy.net:50067/railway")

# %%
table_names = insp.get_table_names(schema='public')
print("table_names:\n", table_names)
# Out:
# table_names:
#  ['categories', 'products', 'customers', 'orders', 'coupons', 'order_items', 'payments', 'shipping', 'inventory', 'reviews']

# %% [raw]
# #Installing packages to send data to snowflake warehouse

# %%
#pip install snowflake-connector-python pandas

# %%
import snowflake.connector
from snowflake.connector.pandas_tools import write_pandas
#imports the helper function that uploads a pandas DataFrame into a Snowflake table

# %%
# Snowflake connection parameters
conn = snowflake.connector.connect(
    user='SPEJU',
    password='#Snowflakes2025',
    account='NZPMXUO-DA03027',  # e.g., 'abcd1234.us-east-1'
    warehouse='COMPUTE_WH',
    database='PEJU_DATABASE2',
    schema='PEJU_SCHEMA2')

# %%
# Create a cursor object to connect to sql 
cursor = conn.cursor()

# %%
#df.columns = [col.upper() for col in df.columns]

# %%
peju_database2 = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    categories_df,
    "categories",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2"
)
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\1574297020.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database2 = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    coupons_df,
    "coupons",
    auto_create_table = True,
    database = peju_database2,
    schema = "PEJU_SCHEMA2",
)
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\2745357514.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
# Define the peju_database variable before using it
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    customer_df,
    "customers",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2"
)
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\3773846722.py:4: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    inventory_df,
    "inventory",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2")
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\282655098.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    orders_df,
    "orders",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2")
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\638441669.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    order_items_df,
    "order_items",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2")
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\830894202.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    payments_df,
    "payments",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2")
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\3398424392.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    reviews_df,
    "reviews",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2")
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\1382582101.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    products_df,
    "products",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2")
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\3588386757.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(

# %%
peju_database = "PEJU_DATABASE2"  # Replace with your actual database name

success, nchunks, nrows, _ = write_pandas(
    conn,
    shipping_df,
    "shipping",
    auto_create_table = True,
    database = peju_database,
    schema = "PEJU_SCHEMA2",
)
# Out:
# C:\Users\userlab\AppData\Local\Temp\ipykernel_24620\949790587.py:3: UserWarning: Dataframe contains a datetime with timezone column, but 'use_logical_type=None'. This can result in datetimes being incorrectly written to Snowflake. Consider setting 'use_logical_type = True'
#   success, nchunks, nrows, _ = write_pandas(
