# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 3.0 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.8 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
source_engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/postgres")

# %%
df = pd.read_sql(f"select * from postgres_schema2.leads", source_engine)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Index       Account Id        Lead Owner First Name   Last Name  \
# 0        1  862d63fBE445C3B    Antonio Savage    Cameron       Price
# 1        2  B1B9fa4B9A41f10  Alexander Mccall    Phyllis        Wade
# 2        3  1c2a1d1Ef8dDEFa       Nancy Grant    Matthew    Villegas
# 3        4  aEAFcec4C129DDE     Yesenia Short      Haley     Chapman
# 4        5  6eA1Ab9d8d03966       Joan Meyers  Priscilla        Tran
# ..     ...              ...               ...        ...         ...
# 995    996  2b3DF6736afc41B       Karla Solis     Andres        Mack
# 996    997  7DE8876cD9feb06     Jaime Alvarez      Kerry  Williamson
# 997    998  49e703C20Ebd4d6      Ruth Cordova       Mark       Singh
# 998    999  e8ABd3EBffA0DD2      Derek Lucero       Drew      Dodson
# 999   1000  E6a6c633B4AD579   Sonia Christian      Billy       Boyle
#
#                           company                Phone 1  \
# ...

# %%
df
# Out:
#      Index       Account Id        Lead Owner First Name   Last Name  \
# 0        1  862d63fBE445C3B    Antonio Savage    Cameron       Price
# 1        2  B1B9fa4B9A41f10  Alexander Mccall    Phyllis        Wade
# 2        3  1c2a1d1Ef8dDEFa       Nancy Grant    Matthew    Villegas
# 3        4  aEAFcec4C129DDE     Yesenia Short      Haley     Chapman
# 4        5  6eA1Ab9d8d03966       Joan Meyers  Priscilla        Tran
# ..     ...              ...               ...        ...         ...
# 995    996  2b3DF6736afc41B       Karla Solis     Andres        Mack
# 996    997  7DE8876cD9feb06     Jaime Alvarez      Kerry  Williamson
# 997    998  49e703C20Ebd4d6      Ruth Cordova       Mark       Singh
# 998    999  e8ABd3EBffA0DD2      Derek Lucero       Drew      Dodson
# 999   1000  E6a6c633B4AD579   Sonia Christian      Billy       Boyle
#
#                           company                Phone 1  \
# 0       Dean, Daniels and Charles           999-826-8118
# ...
