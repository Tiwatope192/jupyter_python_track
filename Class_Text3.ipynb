# %%
import pandas as pd

# %%
df = pd.read_csv("police_killings.csv", encoding = "latin1")

# %%
def extract_data():
    df = pd.read_csv("police_killings.csv", encoding = "latin1")
    return df

# %% [raw]
# df

# %%
df.columns
# Out:
# Index(['name', 'age', 'gender', 'raceethnicity', 'month', 'day', 'year',
#        'streetaddress', 'city', 'state', 'latitude', 'longitude', 'state_fp',
#        'county_fp', 'tract_ce', 'geo_id', 'county_id', 'namelsad',
#        'lawenforcementagency', 'cause', 'armed', 'pop', 'share_white',
#        'share_black', 'share_hispanic', 'p_income', 'h_income',
#        'county_income', 'comp_income', 'county_bucket', 'nat_bucket', 'pov',
#        'urate', 'college'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                    name age  gender    raceethnicity     month  day  year  \
# 0    A'donte Washington  16    Male            Black  February   23  2015
# 1        Aaron Rutledge  27    Male            White     April    2  2015
# 2           Aaron Siler  26    Male            White     March   14  2015
# 3          Aaron Valdez  25    Male  Hispanic/Latino     March   11  2015
# 4          Adam Jovicic  29    Male            White     March   19  2015
# ..                  ...  ..     ...              ...       ...  ...   ...
# 462  William Chapman II  18    Male            Black     April   22  2015
# 463    William Dick III  28    Male  Native American     April    4  2015
# 464       William Poole  52    Male            White     March   16  2015
# 465   Yuvette Henderson  38  Female            Black  February    3  2015
# 466       Zaki Shinwary  48    Male          Unknown   January   16  2015
#
# ...

# %%
df["gender"]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 462      Male
# 463      Male
# 464      Male
# 465    Female
# 466      Male
# Name: gender, Length: 467, dtype: object

# %%
df["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df
# Out:
#                    name age  gender    raceethnicity     month  day  year  \
# 0    A'donte Washington  16    Male            Black  February   23  2015
# 1        Aaron Rutledge  27    Male            White     April    2  2015
# 2           Aaron Siler  26    Male            White     March   14  2015
# 3          Aaron Valdez  25    Male  Hispanic/Latino     March   11  2015
# 4          Adam Jovicic  29    Male            White     March   19  2015
# ..                  ...  ..     ...              ...       ...  ...   ...
# 462  William Chapman II  18    Male            Black     April   22  2015
# 463    William Dick III  28    Male  Native American     April    4  2015
# 464       William Poole  52    Male            White     March   16  2015
# 465   Yuvette Henderson  38  Female            Black  February    3  2015
# 466       Zaki Shinwary  48    Male          Unknown   January   16  2015
#
#                                  streetaddress          city state  ...  \
# ...

# %%
print(df.columns)
# Out:
# Index(['name', 'age', 'gender', 'raceethnicity', 'month', 'day', 'year',
#        'streetaddress', 'city', 'state', 'latitude', 'longitude', 'state_fp',
#        'county_fp', 'tract_ce', 'geo_id', 'county_id', 'namelsad',
#        'lawenforcementagency', 'cause', 'armed', 'pop', 'share_white',
#        'share_black', 'share_hispanic', 'p_income', 'h_income',
#        'county_income', 'comp_income', 'county_bucket', 'nat_bucket', 'pov',
#        'urate', 'college'],
#       dtype='object')

# %%
def transform_data(df):

    df.columns = df.columns.str.replace("_", " ")

    df = df.rename(columns={
        "raceethnicity": "race ethnicity",
        "streetaddress": "street address",
        "lawenforcementagency": "law enforcement agency"
    })

    df.columns = df.columns.str.title()

    return df

# %%
df
# Out:
#                    name age  gender    raceethnicity     month  day  year  \
# 0    A'donte Washington  16    Male            Black  February   23  2015
# 1        Aaron Rutledge  27    Male            White     April    2  2015
# 2           Aaron Siler  26    Male            White     March   14  2015
# 3          Aaron Valdez  25    Male  Hispanic/Latino     March   11  2015
# 4          Adam Jovicic  29    Male            White     March   19  2015
# ..                  ...  ..     ...              ...       ...  ...   ...
# 462  William Chapman II  18    Male            Black     April   22  2015
# 463    William Dick III  28    Male  Native American     April    4  2015
# 464       William Poole  52    Male            White     March   16  2015
# 465   Yuvette Henderson  38  Female            Black  February    3  2015
# 466       Zaki Shinwary  48    Male          Unknown   January   16  2015
#
#                                  streetaddress          city state  ...  \
# ...

# %%
df = extract_data()

df = transform_data(df)

# %%
df
# Out:
#                    Name Age  Gender   Race Ethnicity     Month  Day  Year  \
# 0    A'donte Washington  16    Male            Black  February   23  2015
# 1        Aaron Rutledge  27    Male            White     April    2  2015
# 2           Aaron Siler  26    Male            White     March   14  2015
# 3          Aaron Valdez  25    Male  Hispanic/Latino     March   11  2015
# 4          Adam Jovicic  29    Male            White     March   19  2015
# ..                  ...  ..     ...              ...       ...  ...   ...
# 462  William Chapman II  18    Male            Black     April   22  2015
# 463    William Dick III  28    Male  Native American     April    4  2015
# 464       William Poole  52    Male            White     March   16  2015
# 465   Yuvette Henderson  38  Female            Black  February    3  2015
# 466       Zaki Shinwary  48    Male          Unknown   January   16  2015
#
#                                 Street Address          City State  ...  \
# ...

# %%
df["State"].unique()
# Out:
# array(['AL', 'LA', 'WI', 'CA', 'OH', 'AZ', 'TX', 'MI', 'IN', 'TN', 'GA',
#        'VA', 'NE', 'KS', 'OK', 'OR', 'NH', 'FL', 'MA', 'PA', 'WA', 'AR',
#        'IA', 'NC', 'NM', 'DC', 'ID', 'CO', 'HI', 'KY', 'SC', 'WV', 'UT',
#        'MO', 'MD', 'NY', 'NJ', 'IL', 'CT', 'MS', 'NV', 'MT', 'AK', 'MN',
#        'ME', 'DE', 'WY'], dtype=object)

# %%
state_map = {
    "AL": "Alabama",
    "AK": "Alaska",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "DC": "District of Columbia",
    "FL": "Florida",
    "GA": "Georgia",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PA": "Pennsylvania",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming"
}

# %%
df["State"] = df["State"].map(state_map).fillna(df["State"])

# %%
def transform_data(df):
    df["State"] = df["State"].map(state_map).fillna(df["State"])
    return df

# %%
df
# Out:
#                    Name Age  Gender   Race Ethnicity     Month  Day  Year  \
# 0    A'donte Washington  16    Male            Black  February   23  2015
# 1        Aaron Rutledge  27    Male            White     April    2  2015
# 2           Aaron Siler  26    Male            White     March   14  2015
# 3          Aaron Valdez  25    Male  Hispanic/Latino     March   11  2015
# 4          Adam Jovicic  29    Male            White     March   19  2015
# ..                  ...  ..     ...              ...       ...  ...   ...
# 462  William Chapman II  18    Male            Black     April   22  2015
# 463    William Dick III  28    Male  Native American     April    4  2015
# 464       William Poole  52    Male            White     March   16  2015
# 465   Yuvette Henderson  38  Female            Black  February    3  2015
# 466       Zaki Shinwary  48    Male          Unknown   January   16  2015
#
#                                 Street Address          City           State  \
# ...

# %%
def load_data(df):
    df.to_csv("cleaned_police_killings.csv", index=False)

# %%
df.to_csv( r"C:\Users\userlab\Desktop\peju_python_flow\cleaned_police_killings.csv", index=False)
